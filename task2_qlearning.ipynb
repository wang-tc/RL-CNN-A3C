# %%
# Reload all modules (except those excluded by %aimport) every time before executing the Python code typed.
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import collections
import functools
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import HTML
from numpy.random import default_rng
from matplotlib.animation import FuncAnimation
from task1_environment.environment.main import PacMan
from task1_environment.policy.baseline import blinky_policy
from task1_environment.tool.save_load import save_default_dict, load_default_dict
from task2_qlearning.train import train
from task2_qlearning.eval import check_win_rate, plot_data, prepare_animation
from task2_qlearning.q_policy import q_policy
from task2_qlearning.q_state import simple_state, relative_state
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Animation presentation

# %% [markdown]
# hard mode

# %% [markdown]
# load q table, may take a few seconds

# %%
h_qtable_ani = load_default_dict('./task2_qlearning/qtable/relative.txt')

# %% [markdown]
# initiate game and assign to advance poliy to the enemy 'blinky'

# %%
hard_game_ani = PacMan(maze_row_num=2, maze_column_num=2, maze_row_height=2, maze_column_width=2)
hard_game_ani.blinky.policy = blinky_policy
# wr = check_win_rate(game=h_game, state_func=relative_state, q_table=h_qtable_ani, total_games=1000)

# %% [markdown]
# Generate animation, please run a few times to see how agent perform generally, the two cells above only needs to be run once
#
# Pink --> agent
# bright yellow --> blinky (enemy)
# yellow --> inky (enemy)
# purple --> dots
# orange --> path

# %%
# hard_game_ani = prepare_animation(hard_game_ani, q_policy, simple_state, h_qtable_ani)
hard_game_ani = prepare_animation(hard_game_ani, q_policy, relative_state, h_qtable_ani)
hard_game_ani.generate_animation()
HTML(hard_game_ani.animation.to_jshtml())
# Out:
# Generated frames: 17
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imga47418172138433eaa4cef0b44d3a18b">
#   <div class="anim-controls">
#     <input id="_anim_slidera47418172138433eaa4cef0b44d3a18b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anima47418172138433eaa4cef0b44d3a18b.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anima47418172138433eaa4cef0b44d3a18b.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anima47418172138433eaa4cef0b44d3a18b.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anima47418172138433eaa4cef0b44d3a18b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anima47418172138433eaa4cef0b44d3a18b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anima47418172138433eaa4cef0b44d3a18b.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anima47418172138433eaa4cef0b44d3a18b.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anima47418172138433eaa4cef0b44d3a18b.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anima47418172138433eaa4cef0b44d3a18b.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anima47418172138433eaa4cef0b44d3a18b.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_selecta47418172138433eaa4cef0b44d3a18b"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_a47418172138433eaa4cef0b44d3a18b"
#              >
#       <label for="_anim_radio1_a47418172138433eaa4cef0b44d3a18b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_a47418172138433eaa4cef0b44d3a18b"
#              checked>
#       <label for="_anim_radio2_a47418172138433eaa4cef0b44d3a18b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_a47418172138433eaa4cef0b44d3a18b"
#              >
#       <label for="_anim_radio3_a47418172138433eaa4cef0b44d3a18b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imga47418172138433eaa4cef0b44d3a18b";
#     var slider_id = "_anim_slidera47418172138433eaa4cef0b44d3a18b";
#     var loop_select_id = "_anim_loop_selecta47418172138433eaa4cef0b44d3a18b";
#     var frames = new Array(18);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8vihELAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAfIklEQVR4nO3csa0TQRhGUQ9sBQ5eERRABURETl4ryCWsyKmCxBERFVAARRC4\
# AqOhBl7gu2ufU8EXTDLS1T/mnAcAAAAAAAAAADrv6gEAAAAAAAAAAM9OwAEAAAAAAAAAEBNwAAAA\
# AAAAAADEBBwAAAAAAAAAADEBBwAAAAAAAABATMABAAAAAAAAABATcAAAAAAAAAAAxAQcAAAAAAAA\
# AAAxAQcAAAAAAAAAQEzAAQAAAAAAAA

# %% [markdown]
# easy mode

# %%
e_qtable_ani = load_default_dict('./task2_qlearning/qtable/relative.txt')

# %%
easy_game_ani = PacMan(maze_row_num=3, maze_column_num=3, maze_row_height=2, maze_column_width=2)

# %%
easy_game_ani = prepare_animation(easy_game_ani, q_policy, simple_state, e_qtable_ani)
easy_game_ani.generate_animation()
HTML(easy_game_ani.animation.to_jshtml())
# Out:
# Generated frames: 67
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge589845ae0b44a9cadb8e4c4589a856e">
#   <div class="anim-controls">
#     <input id="_anim_slidere589845ae0b44a9cadb8e4c4589a856e" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime589845ae0b44a9cadb8e4c4589a856e.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anime589845ae0b44a9cadb8e4c4589a856e.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anime589845ae0b44a9cadb8e4c4589a856e.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anime589845ae0b44a9cadb8e4c4589a856e.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anime589845ae0b44a9cadb8e4c4589a856e.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anime589845ae0b44a9cadb8e4c4589a856e.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anime589845ae0b44a9cadb8e4c4589a856e.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anime589845ae0b44a9cadb8e4c4589a856e.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anime589845ae0b44a9cadb8e4c4589a856e.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anime589845ae0b44a9cadb8e4c4589a856e.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_selecte589845ae0b44a9cadb8e4c4589a856e"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e589845ae0b44a9cadb8e4c4589a856e"
#              >
#       <label for="_anim_radio1_e589845ae0b44a9cadb8e4c4589a856e">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e589845ae0b44a9cadb8e4c4589a856e"
#              checked>
#       <label for="_anim_radio2_e589845ae0b44a9cadb8e4c4589a856e">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e589845ae0b44a9cadb8e4c4589a856e"
#              >
#       <label for="_anim_radio3_e589845ae0b44a9cadb8e4c4589a856e">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge589845ae0b44a9cadb8e4c4589a856e";
#     var slider_id = "_anim_slidere589845ae0b44a9cadb8e4c4589a856e";
#     var loop_select_id = "_anim_loop_selecte589845ae0b44a9cadb8e4c4589a856e";
#     var frames = new Array(68);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8vihELAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAfWUlEQVR4nO3csY1TQRhGUQZeBQ7IyIiog4jIybZAQgMuwaIVhOQCCImogQoI\
# XIHFEBJsQIB2rrXvnAo+afSCJ139Y875AgAAAAAAAACAzst6AAAAAAAAAADA3gk4AAAAAAAAAABi\
# Ag4AAAAAAAAAgJiAAwAAAAAAAAAgJuAAAAAAAAAAAIgJOAAAAAAAAAAAYgIOAAAAAAAAAICYgAMA\
# AAAAAAAAICbgAAAAAAAAAACICTgAAA

# %% [markdown]
# # Workflow of task 2 Q-learning from below

# %% [markdown]
# # Set up
# Before training, create q table, which is a default dictionary, return 1 if key does not exist

# %%
q_table = collections.defaultdict(lambda :1)

# %% [markdown]
# Initiate game

# %%
game = PacMan(maze_row_num=2, maze_column_num=2, maze_row_height=2, maze_column_width=2)

# %% [markdown]
# # Training

# %% [markdown]
# start training with hyper-parameters, training function with return
# 1. list of total reward of each game
# 2. list of each mean evaluation reward of 100 (the games_per_eval parameter) games
# 3. list of each mean evaluation total living time
# 4. list of each mean evaluation winning times

# %%
rewards,eval_reward,eval_living_time,eval_win = \
train(
    game=game, 
    state_func=simple_state,
    q_table=q_table,
    total_episode=50000,
    epsilon=0.05,
    alpha=0.05,
    gamma=0.99,
    evaluate_every=1000,
    games_per_eval=100
)
# Out:
# training progress: 100.0%

# %% [markdown]
# # Evaluation
#
# Below is the plot of the total rewards. As the rewards of each game highly fluctuate, it is not clear see the improvement along with time, but we can have a look at the evaluation stats further down.

# %%
plot_data(rewards, 
          './task2_qlearning/graph/reward.jpg', 
          'rewards', 
          'step', 
          'reward'
         )

# %% [markdown]
# This is the plot of evaluation rewards. We can clearly see the improvement.

# %%
plot_data(eval_reward, 
          './task2_qlearning/graph/eval_reward.jpg', 
          'eval_reward', 
          'nth eval', 
          'eval_reward'
         )

# %% [markdown]
# This is the plot of mean living time of the agent in each game during each evaluatition. Again we can see improvement clearly.

# %%
plot_data(eval_living_time, 
          './task2_qlearning/graph/eval_living_time.jpg', 
          'eval_living_time', 
          'nth eval', 
          'living time'
         )

# %% [markdown]
# The plot of total wins of each evaluation (out of 100 games as set above in the training function argument)

# %%
plot_data(eval_win, 
          './task2_qlearning/graph/eval_win_rate.jpg', 
          'win rate with evaluation', 
          'nth eval', 
          'win rate'
         )

# %%
wr = check_win_rate(game=game, state_func=simple_state, q_table=q_table, total_games=1000)
print(f'win rate: {wr:.1%}')
# Out:
# win rate: 69.5%

# %% [markdown]
# save q table

# %%
save_default_dict(q_table, './task2_qlearning/qtable/simple.txt')

# %% [markdown]
# check if q table is successfully saved

# %%
tmp = load_default_dict('./task2_qlearning/qtable/simple.txt')
print(tmp == q_table)
del tmp
# Out:
# True

# %%
len(q_table)
# Out:
# 387762

# %% [markdown]
# # Compare with relative state representation

# %%
qtable_relative = collections.defaultdict(lambda :1)
r_game = PacMan(maze_row_num=2, maze_column_num=2, maze_row_height=2, maze_column_width=2)

# %%
r_rewards,r_eval_reward,r_eval_living_time,r_eval_win = \
train(
    game=r_game, 
    state_func=relative_state,
    q_table=qtable_relative,
    total_episode=50000,
    epsilon=0.05,
    alpha=0.05,
    gamma=0.99,
    evaluate_every=1000,
    games_per_eval=100
)
# Out:
# training progress: 100.0%

# %%
plot_data(r_eval_reward, 
          './task2_qlearning/graph/r_eval_reward.jpg', 
          'eval_reward', 
          'nth eval', 
          'eval_reward'
         )

# %%
plot_data(r_eval_living_time, 
          './task2_qlearning/graph/r_eval_living_time.jpg', 
          'eval_living_time', 
          'nth eval', 
          'living time'
         )

# %%
plot_data(r_eval_win, 
          './task2_qlearning/graph/r_eval_win_rate.jpg', 
          'win rate with evaluation', 
          'nth eval', 
          'win rate'
         )

# %%
wr = check_win_rate(game=r_game, state_func=relative_state, q_table=qtable_relative, total_games=1000)
print(f'win rate: {wr:.1%}')
# Out:
# win rate: 63.5%

# %%
len(qtable_relative)
# Out:
# 171316

# %%
save_default_dict(qtable_relative, './task2_qlearning/qtable/relative.txt')

# %%
# max([v for k,v in qtable_relative.items()])

# %%
tmp = load_default_dict('./task2_qlearning/qtable/relative.txt')
print(tmp == qtable_relative)
del tmp
# Out:
# True

# %% [markdown]
# ### Conclusion
#
# The performance of relative state is about 5% lower than the simple state, but the size of relative state is less than half of the size of simple state. Moreover, due to the smaller size, the Q-learning policy converges very quickly at the early stage of the training. Therefore, the relative state representation will be used to fine tune the hyper paramter due to the limitation of time and computation power.

# %% [markdown]
# # Fine tuning hyper parameter alpha, gamma and epsilon

# %%
qtable_f = collections.defaultdict(lambda :1)
f_game = PacMan(maze_row_num=2, maze_column_num=2, maze_row_height=2, maze_column_width=2)

# %%
alpha_range = np.linspace(0.05, 0.1, 2)
gamma_range = np.linspace(0.9, 1, 2)
epsilon_range = np.linspace(0.05, 0.1, 2)
print(alpha_range, gamma_range, epsilon_range)
# Out:
# [0.05 0.1 ] [0.9 1. ] [0.05 0.1 ]

# %%
metric = np.zeros((2,2,2))

# %%
for i, alpha in enumerate(alpha_range):
    for j, gamma in enumerate(gamma_range):
        for k, epsilon in enumerate(epsilon_range):
            qtable_f = qtable_f = collections.defaultdict(lambda :1)
            f_game = PacMan(maze_row_num=2, maze_column_num=2, maze_row_height=2, maze_column_width=2)
            _,_,f_eval_living_time,_ = \
            train(
                game=f_game, 
                state_func=relative_state,
                q_table=qtable_f,
                total_episode=5000,
                epsilon=epsilon,
                alpha=alpha,
                gamma=gamma,
                evaluate_every=5000,
                games_per_eval=100
            )
            metric[i,j,k]=f_eval_living_time[-1]
# Out:
# training progress: 100.0%

# %%
metric
# Out:
# array([[[16.  , 13.99],
#         [14.73, 18.32]],
#
#        [[13.02, 16.1 ],
#         [14.89, 17.42]]])

# %%
for i, alpha in enumerate(alpha_range):
    for j, gamma in enumerate(gamma_range):
        for k, epsilon in enumerate(epsilon_range):
            print(f'average living time with alpha: {alpha}, gamma: {gamma}, epsilon: {epsilon} -----> {metric[i,j,k]}')
# Out:
# average living time with alpha: 0.05, gamma: 0.9, epsilon: 0.05 -----> 16.0
# average living time with alpha: 0.05, gamma: 0.9, epsilon: 0.1 -----> 13.99
# average living time with alpha: 0.05, gamma: 1.0, epsilon: 0.05 -----> 14.73
# average living time with alpha: 0.05, gamma: 1.0, epsilon: 0.1 -----> 18.32
# average living time with alpha: 0.1, gamma: 0.9, epsilon: 0.05 -----> 13.02
# average living time with alpha: 0.1, gamma: 0.9, epsilon: 0.1 -----> 16.1
# average living time with alpha: 0.1, gamma: 1.0, epsilon: 0.05 -----> 14.89
# average living time with alpha: 0.1, gamma: 1.0, epsilon: 0.1 -----> 17.42

# %% [markdown]
# The best hypyter paramters for early stage training are alpha 0.05, gamma 1.0 epsilon 0.1 in this comparison.

# %% [markdown]
# # Would it work to use the same Q table for the harder mode?
#
# The enemy ghost will chase the agent forever by setting
# ```
# h_game.blinky.policy = blinky_policy
# ```

# %%
h_game = PacMan(maze_row_num=2, maze_column_num=2, maze_row_height=2, maze_column_width=2)
h_game.blinky.policy = blinky_policy

# %%
simple_qtable = load_default_dict('./task2_qlearning/qtable/simple.txt')

# %% [markdown]
# It seems to work even though the performance drop significantly.

# %%
wr = check_win_rate(game=h_game, state_func=simple_state, q_table=simple_qtable, total_games=1000)
print(f'win rate: {wr:.1%}')
# Out:
# win rate: 15.9%

# %%
relative_qtable = load_default_dict('./task2_qlearning/qtable/relative.txt')

# %% [markdown]
# The relative state representation policy also works, the performance is slightly lower than the simple state policy.

# %%
# wr = check_win_rate(game=h_game, state_func=relative_state, q_table=relative_qtable, total_games=1000)
wr = check_win_rate(game=h_game, state_func=relative_state, q_table=h_qtable_ani, total_games=1000)
print(f'win rate: {wr:.1%}')
# Out:
# win rate: 12.8%

# %% [markdown]
# ### training from sctrach for the harder mode

# %%
h_qtable_simple = collections.defaultdict(lambda :1)
_, _, _, h_eval_win = train(
    game=h_game, 
    state_func=simple_state,
    q_table=h_qtable_simple,
    total_episode=50000,
    epsilon=0.05,
    alpha=0.05,
    gamma=0.99,
    evaluate_every=1000,
    games_per_eval=100
)
# Out:
# training progress: 100.0%

# %%
plot_data(h_eval_win, 
          './task2_qlearning/graph/simple_eval_win_rate_hard_mode.jpg', 
          'win rate with evaluation', 
          'nth eval', 
          'win rate'
         )

# %%
wr = check_win_rate(game=h_game, state_func=simple_state, q_table=h_qtable_simple, total_games=1000)
print(f'win rate: {wr:.1%}')
# Out:
# win rate: 37.6%

# %% [markdown]
# The performance is still increasting at the same speed, would be interesting to see what the performance will be after training another 50000 steps

# %%
_, _, _, h_eval_win = train(
    game=h_game, 
    state_func=simple_state,
    q_table=h_qtable_simple,
    total_episode=50000,
    epsilon=0.05,
    alpha=0.05,
    gamma=0.99,
    evaluate_every=1000,
    games_per_eval=100
)
# Out:
# training progress: 100.0%

# %%
plot_data(h_eval_win, 
          './task2_qlearning/graph/simple_eval_win_rate_hard_mode.jpg', 
          'win rate with evaluation', 
          'nth eval', 
          'win rate'
         )

# %%
wr = check_win_rate(game=h_game, state_func=simple_state, q_table=h_qtable_simple, total_games=1000)
print(f'win rate: {wr:.1%}')
# Out:
# win rate: 57.5%

# %%
save_default_dict(h_qtable_simple, './task2_qlearning/qtable/h_qtable_simple.txt')

# %%
tmp = load_default_dict('./task2_qlearning/qtable/h_qtable_simple.txt')
print(tmp == h_qtable_simple)
del tmp
# Out:
# True

# %% [markdown]
# Conclusion
#
# The performance is good and it may still improve with further training.

# %% [markdown]
# ### training from sctrach for the harder mode
